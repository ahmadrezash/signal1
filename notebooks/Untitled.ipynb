# %%
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.io import loadmat

# %%
mat = loadmat('.././New_Shuffled_Train(normal)/subj_6.mat')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/signal/lib/python3.7/site-packages/scipy/io/matlab/mio.py in _open_file(file_like, appendmat, mode)
#      38     try:
# ---> 39         return open(file_like, mode), True
#      40     except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '.././New_Shuffled_Train(normal)/subj_6.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-967c4d5d4ea0> in <module>
# ----> 1 mat = loadmat('.././New_Shuffled_Train(normal)/subj_6.mat')
#
# ~/anaconda3/envs/signal/lib/python3.7/site-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     214     """
#     215     variable_names = kwargs.pop('variable_names', None)
# ...

# %%
a = mat['subj_6'].T
import os

dataDir = "/some/folder/containing/data/"
# mats = []
# for file in os.listdir( dataDir ) :
#     mats.append( scipy.io.loadmat( dataDir+file ) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0a975e86167f> in <module>
# ----> 1 a = mat['subj_6'].T
#       2 import os
#       3
#       4 dataDir = "/some/folder/containing/data/"
#       5 # mats = []
#
# NameError: name 'mat' is not defined

# %%
plt.figure(figsize=(200,80))
plt.plot(a[0],linewidth=5)
plt.plot(a[1],linewidth=5)

# %%
import os

dataDir = "/home/ahmad/Project/BrainSignal/New_Shuffled_Train_normal/"
mats = []
for file in os.listdir( dataDir ) :
    mats.append( loadmat( dataDir+file )[file[:-4]] )
    print(file)
# Out:
# subj_95.mat
# subj_51.mat
# subj_31.mat
# subj_11.mat
# subj_42.mat
# subj_10.mat
# subj_3.mat
# subj_94.mat
# subj_1.mat
# subj_33.mat
# subj_124.mat
# subj_29.mat
# subj_53.mat
# subj_88.mat
# subj_108.mat
# subj_129.mat
# subj_17.mat
# subj_69.mat
# subj_40.mat
# subj_132.mat
# subj_27.mat
# subj_26.mat
# subj_80.mat
# subj_50.mat
# subj_114.mat
# subj_24.mat
# subj_16.mat
# subj_96.mat
# subj_2.mat
# subj_109.mat
# subj_52.mat
# subj_19.mat
# subj_21.mat
# subj_118.mat
# subj_128.mat
# subj_91.mat
# subj_35.mat
# subj_70.mat
# subj_98.mat
# subj_103.mat
# subj_97.mat
# subj_34.mat
# subj_14.mat
# subj_46.mat
# subj_18.mat
# subj_123.mat
# subj_4.mat
# subj_41.mat
# subj_60.mat
# subj_68.mat
# subj_110.mat
# subj_83.mat
# subj_115.mat
# subj_76.mat
# subj_90.mat
# subj_20.mat
# subj_45.mat
# subj_15.mat
# subj_30.mat
# subj_130.mat
# subj_119.mat
# subj_23.mat
# subj_106.mat
# subj_84.mat
# subj_58.mat
# subj_116.mat
# subj_85.mat
# subj_93.mat
# subj_65.mat
# subj_56.mat
# ...

# %%
for i in mats:
    print(i.shape)
# Out:
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# (15360, 19)
# ...

# %%
# import regx
np.fromregex
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-15f0d0929b26> in <module>
#       1 # import regx
#       2 import numpy as np
# ----> 3 np.fromregex('*2')
#
# TypeError: fromregex() missing 2 required positional arguments: 'regexp' and 'dtype'
